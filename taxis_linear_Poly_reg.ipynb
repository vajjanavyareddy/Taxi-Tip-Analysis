# %%
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset("taxis")

# %%
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df.describe()
# Out:
#                               pickup                        dropoff  \
# count                           6433                           6433
# mean   2019-03-16 08:31:28.514223616  2019-03-16 08:45:49.491217408
# min              2019-02-28 23:29:03            2019-02-28 23:32:35
# 25%              2019-03-08 15:50:34            2019-03-08 16:12:51
# 50%              2019-03-15 21:46:58            2019-03-15 22:06:44
# 75%              2019-03-23 17:41:38            2019-03-23 17:51:56
# max              2019-03-31 23:43:45            2019-04-01 00:13:58
# std                              NaN                            NaN
#
#         passengers     distance         fare         tip        tolls  \
# count  6433.000000  6433.000000  6433.000000  6433.00000  6433.000000
# mean      1.539251     3.024617    13.091073     1.97922     0.325273
# min       0.000000     0.000000     1.000000     0.00000     0.000000
# 25%       1.000000     0.980000     6.500000     0.00000     0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6433 non-null   datetime64[ns]
#  1   dropoff          6433 non-null   datetime64[ns]
#  2   passengers       6433 non-null   int64
#  3   distance         6433 non-null   float64
#  4   fare             6433 non-null   float64
#  5   tip              6433 non-null   float64
#  6   tolls            6433 non-null   float64
#  7   total            6433 non-null   float64
#  8   color            6433 non-null   object
#  9   payment          6389 non-null   object
#  10  pickup_zone      6407 non-null   object
#  11  dropoff_zone     6388 non-null   object
#  12  pickup_borough   6407 non-null   object
#  13  dropoff_borough  6388 non-null   object
# dtypes: datetime64[ns](2), float64(5), int64(1), object(6)
# memory usage: 703.7+ KB

# %%
df.shape
# Out:
# (6433, 14)

# %%
df.columns
# Out:
# Index(['pickup', 'dropoff', 'passengers', 'distance', 'fare', 'tip', 'tolls',
#        'total', 'color', 'payment', 'pickup_zone', 'dropoff_zone',
#        'pickup_borough', 'dropoff_borough'],
#       dtype='object')

# %%
df.describe(include="object")
# Out:
#          color      payment     pickup_zone           dropoff_zone  \
# count     6433         6389            6407                   6388
# unique       2            2             194                    203
# top     yellow  credit card  Midtown Center  Upper East Side North
# freq      5451         4577             230                    245
#
#        pickup_borough dropoff_borough
# count            6407            6388
# unique              4               5
# top         Manhattan       Manhattan
# freq             5268            5206

# %%
df.describe(include="all")
# Out:
#                                pickup                        dropoff  \
# count                            6433                           6433
# unique                            NaN                            NaN
# top                               NaN                            NaN
# freq                              NaN                            NaN
# mean    2019-03-16 08:31:28.514223616  2019-03-16 08:45:49.491217408
# min               2019-02-28 23:29:03            2019-02-28 23:32:35
# 25%               2019-03-08 15:50:34            2019-03-08 16:12:51
# 50%               2019-03-15 21:46:58            2019-03-15 22:06:44
# 75%               2019-03-23 17:41:38            2019-03-23 17:51:56
# max               2019-03-31 23:43:45            2019-04-01 00:13:58
# std                               NaN                            NaN
#
#          passengers     distance         fare         tip        tolls  \
# ...

# %%
df.isna().sum()
# Out:
# pickup              0
# dropoff             0
# passengers          0
# distance            0
# fare                0
# tip                 0
# tolls               0
# total               0
# color               0
# payment            44
# pickup_zone        26
# dropoff_zone       45
# pickup_borough     26
# dropoff_borough    45
# dtype: int64

# %%
(df.isna().sum()/df.shape[0])*100
# Out:
# pickup             0.000000
# dropoff            0.000000
# passengers         0.000000
# distance           0.000000
# fare               0.000000
# tip                0.000000
# tolls              0.000000
# total              0.000000
# color              0.000000
# payment            0.683973
# pickup_zone        0.404166
# dropoff_zone       0.699518
# pickup_borough     0.404166
# dropoff_borough    0.699518
# dtype: float64

# %%
((df.shape[0]-df.dropna().shape[0])/df.shape[0])*100
# Out:
# 1.4301259132597544

# %%
df.dropna()
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (6341, 14)

# %%
df.describe()
# Out:
#                               pickup                        dropoff  \
# count                           6341                           6341
# mean   2019-03-16 08:30:26.574830080  2019-03-16 08:44:47.525784832
# min              2019-02-28 23:29:03            2019-02-28 23:32:35
# 25%              2019-03-08 15:28:20            2019-03-08 15:54:00
# 50%              2019-03-15 21:57:47            2019-03-15 22:07:48
# 75%              2019-03-23 17:45:29            2019-03-23 17:57:56
# max              2019-03-31 23:43:45            2019-04-01 00:13:58
# std                              NaN                            NaN
#
#         passengers     distance         fare          tip        tolls  \
# count  6341.000000  6341.000000  6341.000000  6341.000000  6341.000000
# mean      1.544078     2.997707    12.887931     1.972703     0.314793
# min       0.000000     0.000000     1.000000     0.000000     0.000000
# ...

# %%
df.describe(include="object")
# Out:
#          color      payment     pickup_zone           dropoff_zone  \
# count     6341         6341            6341                   6341
# unique       2            2             194                    203
# top     yellow  credit card  Midtown Center  Upper East Side North
# freq      5373         4546             227                    244
#
#        pickup_borough dropoff_borough
# count            6341            6341
# unique              4               5
# top         Manhattan       Manhattan
# freq             5226            5172

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6336 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6337 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6338 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6339 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6340 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df.describe()
# Out:
#                               pickup                        dropoff  \
# count                           6341                           6341
# mean   2019-03-16 08:30:26.574830080  2019-03-16 08:44:47.525784832
# min              2019-02-28 23:29:03            2019-02-28 23:32:35
# 25%              2019-03-08 15:28:20            2019-03-08 15:54:00
# 50%              2019-03-15 21:57:47            2019-03-15 22:07:48
# 75%              2019-03-23 17:45:29            2019-03-23 17:57:56
# max              2019-03-31 23:43:45            2019-04-01 00:13:58
# std                              NaN                            NaN
#
#         passengers     distance         fare          tip        tolls  \
# count  6341.000000  6341.000000  6341.000000  6341.000000  6341.000000
# mean      1.544078     2.997707    12.887931     1.972703     0.314793
# min       0.000000     0.000000     1.000000     0.000000     0.000000
# ...

# %%
df.shape
# Out:
# (6341, 14)

# %%
df.isna().sum()
# Out:
# pickup             0
# dropoff            0
# passengers         0
# distance           0
# fare               0
# tip                0
# tolls              0
# total              0
# color              0
# payment            0
# pickup_zone        0
# dropoff_zone       0
# pickup_borough     0
# dropoff_borough    0
# dtype: int64

# %% [markdown]
# EDA

# %% [markdown]
# tip column is the target  column of data

# %% [markdown]
# tip is a numneriacl feature, analyse with color feature which is categorical data

# %%
df.color.value_counts()
# Out:
# color
# yellow    5373
# green      968
# Name: count, dtype: int64

# %% [markdown]
# 2 unique categories

# %% [markdown]
# Graphical analysis of Categorical data

# %%
sns.barplot(x="color", y="tip", data=df, estimator='std')
# Out:
# <Axes: xlabel='color', ylabel='tip'>

# %% [markdown]
# 1. Yellow has higher avg tip
# 2. Yellow has  larger std - tips vary a lot
# 3. Green has lower avg but small std- tips are consistent
# 4. bigger bar = more uncertainity

# %%
sns.barplot(x="color", y="tip", data=df, estimator='mean')
# Out:
# <Axes: xlabel='color', ylabel='tip'>

# %% [markdown]
# 1. yellow category has a higher avg tip
# 2. green category has a lower avg tip
# 3. customers associated with yellow tends to give higher tips comapared to green
# 4. gap btw the bars indicates color has a strong influence on tip

# %%
import matplotlib.pyplot as plt

# %%
sns.histplot(x=df.tip, hue=df.color, kde=True,palette={'yellow':'yellow','green':'green'})
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# 1. Yellow tips are generally high,
# highest peak around 2-3,
# extends to very high i.e 20+
# 2. Green tips are mostly low,
# high near 0-2,
# may be goes beyond 3-4
# 3. Yellow has much higher count than green

# %%
import pandas as pd
import numpy as np
from scipy import stats
import statsmodels.api as sm
from statsmodels.stats.weightstats import ztest
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# %% [markdown]
# Hypotheses:
#
#   H0: distribution of tip for yellow = distribution of tip for green
#   H1:  distribution of tip for yellow ≠ distribution of tip for green

# %%
# Independent T-Test
yellow_tip = df[df['color']=='yellow']['tip']
green_tip = df[df['color']=='green']['tip']

t_stat, p_val = stats.ttest_ind(yellow_tip, green_tip)
print("Independent T-Test statistic:", t_stat)
print("P-value:", p_val)

if p_val  < 0.05:
    print("Reject null hypothesis: Tip differs by Color")
else:
    print("Fail to reject null hypothesis: No significant tip difference by Color")
# Out:
# Independent T-Test statistic: 17.05932566128597
# P-value: 7.791088119489451e-64
# Reject null hypothesis: Tip differs by Color

# %%
yellow_tip
# Out:
# 0       2.15
# 1       0.00
# 2       2.36
# 3       6.15
# 4       1.10
#         ...
# 5368    2.66
# 5369    2.36
# 5370    2.56
# 5371    2.36
# 5372    1.33
# Name: tip, Length: 5373, dtype: float64

# %%
green_tip
# Out:
# 5373    0.00
# 5374    0.00
# 5375    1.20
# 5376    0.00
# 5377    0.00
#         ...
# 6336    1.06
# 6337    0.00
# 6338    0.00
# 6339    0.00
# 6340    3.36
# Name: tip, Length: 968, dtype: float64

# %%
df.columns
# Out:
# Index(['pickup', 'dropoff', 'passengers', 'distance', 'fare', 'tip', 'tolls',
#        'total', 'color', 'payment', 'pickup_zone', 'dropoff_zone',
#        'pickup_borough', 'dropoff_borough'],
#       dtype='object')

# %%
df.payment.value_counts()
# Out:
# payment
# credit card    4546
# cash           1795
# Name: count, dtype: int64

# %%
sns.barplot(x="payment", y="tip", data=df, estimator='mean')
# Out:
# <Axes: xlabel='payment', ylabel='tip'>

# %% [markdown]
# Insights:
# 1. credit card users usually pay tip
# 2. Cash users do not tip
# 3. Payment method strongly influences tipping behaviour

# %%
sns.barplot(x="payment", y="tip", data=df, estimator='std')
# Out:
# <Axes: xlabel='payment', ylabel='tip'>

# %% [markdown]
# Insights:
# 1. std = 0 for cash payments
# 2. std>0 - people tip diff amounts

# %%
df.groupby("payment")["tip"].mean()
# Out:
# payment
# cash           0.00000
# credit card    2.75163
# Name: tip, dtype: float64

# %%
sns.histplot(x=df.tip, hue=df.payment, kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# 1. Payment method strongly affects tipping behaviour
# 2. Encourage credit card payments
# 3. Cash payments result in 0 tips

# %% [markdown]
# Hypotheses:
#
# H0: distribution of tip for credit card = distribution of tip for cash
# H1: distribution of tip for credit card ≠ distribution of tip for cash

# %%
# Independent T-Test
card_tip = df[df['payment']=='credit card']['tip']
cash_tip = df[df['payment']=='cash']['tip']

t_stat, p_val = stats.ttest_ind(card_tip, cash_tip)
print("Independent T-Test statistic:", t_stat)
print("P-value:", p_val)

if p_val  < 0.05:
    print("Reject null hypothesis: Tip differs by Payment")
else:
    print("Fail to reject null hypothesis: No significant tip difference by Payment")
# Out:
# Independent T-Test statistic: 49.09538452722153
# P-value: 0.0
# Reject null hypothesis: Tip differs by Payment

# %%
df['pickup_borough'].unique()
# Out:
# array(['Manhattan', 'Queens', 'Bronx', 'Brooklyn'], dtype=object)

# %%
df['pickup_borough'].value_counts()
# Out:
# pickup_borough
# Manhattan    5226
# Queens        638
# Brooklyn      378
# Bronx          99
# Name: count, dtype: int64

# %%
sns.countplot(x=df['pickup_borough'])
# Out:
# <Axes: xlabel='pickup_borough', ylabel='count'>

# %%
sns.barplot(x="pickup_borough", y="tip", data=df, estimator='mean')
# Out:
# <Axes: xlabel='pickup_borough', ylabel='tip'>

# %%
df['tip'].groupby(df['pickup_borough']).mean()
# Out:
# pickup_borough
# Bronx        0.148586
# Brooklyn     0.979127
# Manhattan    1.945597
# Queens       3.066458
# Name: tip, dtype: float64

# %%
sns.barplot(x="pickup_borough", y="tip", data=df, estimator='std')
# Out:
# <Axes: xlabel='pickup_borough', ylabel='tip'>

# %%
df['tip'].groupby(df['pickup_borough']).std()
# Out:
# pickup_borough
# Bronx        0.897261
# Brooklyn     1.674487
# Manhattan    1.997736
# Queens       4.323951
# Name: tip, dtype: float64

# %%
sns.histplot(x=df.tip, hue=df.pickup_borough, kde=True,bins=20)
plt.show()

# %% [markdown]
# Hypotheses:
#
# H0: Distribution of tip is the same across all pickup_borough categories
# H1: At least one category  has a different distribution of tip

# %%
manhattan_tip = df[df['pickup_borough']=='Manhattan']['tip']
queens_tip = df[df['pickup_borough']=='Queens']['tip']
bronx_tip = df[df['pickup_borough']=='Bronx']['tip']
brooklyn_tip = df[df['pickup_borough']=='Brooklyn']['tip']

# %%
# ANOVA Test
f_stat, p_val = stats.f_oneway(manhattan_tip,queens_tip,bronx_tip,brooklyn_tip)
print("ANOVA F-statistic:", f_stat)
print("P-value:", p_val)

if p_val < 0.05:
    print("Reject null hypothesis: At least one category has a different distribution of tip")
else:
    print("Fail to reject null hypothesis: Distribution of tip is the same across all pickup_borough categories")
# Out:
# ANOVA F-statistic: 91.5793383185057
# P-value: 5.155109332422435e-58
# Reject null hypothesis: At least one category has a different distribution of tip

# %% [markdown]
# H0: Distribution of group1 = Distribution of group2
# H1: Distribution of group1  ≠ Distribution of group2

# %%
# Tukey HSD Test
from statsmodels.stats.multicomp import pairwise_tukeyhsd



# Perform Tukey HSD
tukey_result = pairwise_tukeyhsd(endog=df.tip, groups=df.pickup_borough, alpha=0.05)
print(tukey_result)
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#   group1    group2  meandiff p-adj lower  upper  reject
# -------------------------------------------------------
#     Bronx  Brooklyn   0.8305 0.008 0.1595 1.5015   True
#     Bronx Manhattan    1.797   0.0  1.194    2.4   True
#     Bronx    Queens   2.9179   0.0 2.2759 3.5599   True
#  Brooklyn Manhattan   0.9665   0.0 0.6499  1.283   True
#  Brooklyn    Queens   2.0873   0.0 1.7016 2.4731   True
# Manhattan    Queens   1.1209   0.0 0.8716 1.3701   True
# -------------------------------------------------------

# %%
df['dropoff_borough'].unique()
# Out:
# array(['Manhattan', 'Queens', 'Brooklyn', 'Bronx', 'Staten Island'],
#       dtype=object)

# %%
df['dropoff_borough'].value_counts()
# Out:
# dropoff_borough
# Manhattan        5172
# Queens            534
# Brooklyn          497
# Bronx             136
# Staten Island       2
# Name: count, dtype: int64

# %%
sns.countplot(x=df['dropoff_borough'],data=df,
    hue='dropoff_borough',palette='Set1')
# Out:
# <Axes: xlabel='dropoff_borough', ylabel='count'>

# %%
sns.barplot(
    x="dropoff_borough",
    y="tip",
    data=df,
    estimator='mean',
    hue="dropoff_borough",
    palette="Set2",
    legend=False
)
# Out:
# <Axes: xlabel='dropoff_borough', ylabel='tip'>

# %%
df['tip'].groupby(df['dropoff_borough']).mean()
# Out:
# dropoff_borough
# Bronx             0.534706
# Brooklyn          1.921590
# Manhattan         1.964321
# Queens            2.422022
# Staten Island    14.165000
# Name: tip, dtype: float64

# %%
sns.barplot(x="dropoff_borough", y="tip",hue = "dropoff_borough", data=df, estimator='std',palette='Set2')
# Out:
# <Axes: xlabel='dropoff_borough', ylabel='tip'>

# %%
df['tip'].groupby(df['dropoff_borough']).std()
# Out:
# dropoff_borough
# Bronx            1.788795
# Brooklyn         2.896229
# Manhattan        2.052074
# Queens           3.947016
# Staten Island    2.976920
# Name: tip, dtype: float64

# %%
sns.histplot(x=df.tip, hue=df.dropoff_borough, kde=True,bins=20)
plt.show()

# %% [markdown]
# Hypotheses:
#
# H0: Distribution of tip is the same across all dropoff_borough categories
#
# H1: At least one category has a different distribution of tip

# %%
manhattan_tip = df[df['dropoff_borough']=='Manhattan']['tip']
queens_tip = df[df['dropoff_borough']=='Queens']['tip']
bronx_tip = df[df['dropoff_borough']=='Bronx']['tip']
brooklyn_tip = df[df['dropoff_borough']=='Brooklyn']['tip']
staten_tip = df[df['dropoff_borough']=='Staten Island']['tip']

# %%
# ANOVA Test
f_stat, p_val = stats.f_oneway(manhattan_tip,queens_tip,bronx_tip,brooklyn_tip,staten_tip)
print("ANOVA F-statistic:", f_stat)
print("P-value:", p_val)

if p_val < 0.05:
    print("Reject null hypothesis: At least one category has a different distribution of tip")
else:
    print("Fail to reject null hypothesis: Distribution of tip is the same across all pickup_borough categories")
# Out:
# ANOVA F-statistic: 31.42417796696829
# P-value: 5.87859571331583e-26
# Reject null hypothesis: At least one category has a different distribution of tip

# %% [markdown]
# H0: Distribution of group1 = Distribution of group2 H1: Distribution of group1 ≠ Distribution of group2

# %%
# Tukey HSD Test
from statsmodels.stats.multicomp import pairwise_tukeyhsd
# Perform Tukey HSD
tukey_result = pairwise_tukeyhsd(endog=df.tip, groups=df.dropoff_borough, alpha=0.05)
print(tukey_result)
# Out:
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#   group1      group2    meandiff p-adj   lower   upper  reject
# --------------------------------------------------------------
#     Bronx      Brooklyn   1.3869    0.0  0.7691  2.0046   True
#     Bronx     Manhattan   1.4296    0.0  0.8751  1.9842   True
#     Bronx        Queens   1.8873    0.0  1.2742  2.5005   True
#     Bronx Staten Island  13.6303    0.0  9.0833 18.1773   True
#  Brooklyn     Manhattan   0.0427 0.9952 -0.2571  0.3425  False
#  Brooklyn        Queens   0.5004 0.0055  0.1026  0.8983   True
#  Brooklyn Staten Island  12.2434    0.0  7.7204 16.7664   True
# Manhattan        Queens   0.4577 0.0002  0.1675  0.7479   True
# Manhattan Staten Island  12.2007    0.0  7.6859 16.7154   True
#    Queens Staten Island   11.743    0.0  7.2206 16.2653   True
# --------------------------------------------------------------

# %%
df.columns
# Out:
# Index(['pickup', 'dropoff', 'passengers', 'distance', 'fare', 'tip', 'tolls',
#        'total', 'color', 'payment', 'pickup_zone', 'dropoff_zone',
#        'pickup_borough', 'dropoff_borough'],
#       dtype='object')

# %%
df.head(5)
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# ...

# %%
df['pickup_zone'].unique()
# Out:
# array(['Lenox Hill West', 'Upper West Side South', 'Alphabet City',
#        'Hudson Sq', 'Midtown East', 'Times Sq/Theatre District',
#        'Battery Park City', 'East Harlem South', 'Lincoln Square East',
#        'LaGuardia Airport', 'Murray Hill', 'Lincoln Square West',
#        'Financial District North', 'Upper West Side North',
#        'East Chelsea', 'Midtown Center', 'Gramercy',
#        'Penn Station/Madison Sq West', 'Sutton Place/Turtle Bay North',
#        'West Chelsea/Hudson Yards', 'Clinton East', 'Clinton West',
#        'UN/Turtle Bay South', 'Midtown South', 'Midtown North',
#        'Garment District', 'Lenox Hill East', 'Flatiron',
#        'TriBeCa/Civic Center', 'Upper East Side North', 'West Village',
#        'Greenwich Village South', 'JFK Airport', 'East Village',
#        'Union Sq', 'Yorkville West', 'Central Park',
#        'Meatpacking/West Village West', 'Kips Bay', 'Morningside Heights',
#        'Astoria', 'East Tremont', 'Upper East Side South',
# ...

# %%
df['pickup_zone'].value_counts()
# Out:
# pickup_zone
# Midtown Center                  227
# Penn Station/Madison Sq West    209
# Clinton East                    208
# Upper East Side South           208
# Midtown East                    196
#                                ...
# Ozone Park                        1
# Glendale                          1
# Woodlawn/Wakefield                1
# West Farms/Bronx River            1
# Hillcrest/Pomonok                 1
# Name: count, Length: 194, dtype: int64

# %%
len(df['pickup_zone'].unique())
# Out:
# 194

# %%
len(df['pickup_zone'].value_counts())
# Out:
# 194

# %%
sns.countplot(x=df['pickup_zone'])
plt.show()

# %%
sns.countplot(x= df['dropoff_zone'])
plt.show()

# %%
# ANOVA Test
categories = [group['tip'].values for name, group in df.groupby('pickup_zone')]
f_stat, p_val = stats.f_oneway(*categories)
print("ANOVA F-statistic:", f_stat)
print("P-value:", p_val)

if p_val < 0.05:
    print("Reject null hypothesis: ")
else:
    print("Fail to reject null hypothesis:")
# Out:
# ANOVA F-statistic: 7.563376210961916
# P-value: 7.892434822136223e-169
# Reject null hypothesis:

# %% [markdown]
# Insights:
# 1. Pickup zone significantly affects the amount of tip
# 2. Pickup location influences customer tipping behaviour

# %%
# ANOVA Test
categories = [group['tip'].values for name, group in df.groupby('dropoff_zone')]
f_stat, p_val = stats.f_oneway(*categories)
print("ANOVA F-statistic:", f_stat)
print("P-value:", p_val)

if p_val < 0.05:
    print("Reject null hypothesis:")
else:
    print("Fail to reject null hypothesis: ")
# Out:
# ANOVA F-statistic: 5.76903467327541
# P-value: 1.3107168403745948e-120
# Reject null hypothesis:

# %% [markdown]
# Insights:
# 1. Destination matters for tipping
# 2. Pickup zone has stronger influence than drop-off zone

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6341 entries, 0 to 6340
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6341 non-null   datetime64[ns]
#  1   dropoff          6341 non-null   datetime64[ns]
#  2   passengers       6341 non-null   int64
#  3   distance         6341 non-null   float64
#  4   fare             6341 non-null   float64
#  5   tip              6341 non-null   float64
#  6   tolls            6341 non-null   float64
#  7   total            6341 non-null   float64
#  8   color            6341 non-null   object
#  9   payment          6341 non-null   object
#  10  pickup_zone      6341 non-null   object
#  11  dropoff_zone     6341 non-null   object
#  12  pickup_borough   6341 non-null   object
#  13  dropoff_borough  6341 non-null   object
# dtypes: datetime64[ns](2), float64(5), int64(1), object(6)
# memory usage: 693.7+ KB

# %%
sns.histplot(df['tip'],kde = True)
plt.show()

# %% [markdown]
# above graoh has outliers and right skewed

# %%
sns.histplot(df['passengers'],kde = True)
plt.show()

# %%
sns.scatterplot(x=df['tip'],y=df['passengers'])
plt.show()

# %%
df['passengers'].skew()
# Out:
# np.float64(2.349366327837006)

# %%
df['passengers'].kurtosis()
# Out:
# np.float64(4.8167003036423175)

# %% [markdown]
# Hypothesis for correlation for numeric variables
# H0: correlation is zero
# H1: there is significant correlation (not zero)

# %%
r,p_val = stats.pearsonr(df['tip'],df['fare'])
print("Pearson correlation coefficient:", r)
print("P-value:", p_val)
alpha = 0.05
if p_val< alpha:
  print("Reject null hypothesis")
else:
  print("Fail to reject null hypothesis")
# Out:
# Pearson correlation coefficient: 0.48710089077355956
# P-value: 0.0
# Reject null hypothesis

# %%
r,p_val = stats.spearmanr(df['tip'],df['passengers'])
print("correlation coefficient:", r)
print("P-value:", p_val)
alpha = 0.05
if p_val< alpha:
  print("Reject null hypothesis: There is no relationship")
else:
  print("Fail to reject null hypothesis: There is significant relationship")
# Out:
# correlation coefficient: 0.027509812818779178
# P-value: 0.028480753176042872
# Reject null hypothesis: There is no relationship

# %%
sns.histplot(df['fare'],kde = True,bins = 20)
plt.show()

# %%
sns.scatterplot(x=df['tip'],y=df['fare'])
# Out:
# <Axes: xlabel='tip', ylabel='fare'>

# %%
df['fare'].skew()
# Out:
# np.float64(2.606558389580325)

# %%
df['fare'].kurtosis()
# Out:
# np.float64(10.170827993181963)

# %% [markdown]
# Hypothesis for correlation for numeric variables
# H0: correlation is zero
# H1: there is significant correlation (not zero)

# %%
r,p_val = stats.spearmanr(df['tip'],df['fare'])
print("correlation coefficient:", r)
print("P-value:", p_val)
alpha = 0.05
if p_val< alpha:
  print("Reject null hypothesis: There is no relationship")
else:
  print("Fail to reject null hypothesis: There is significant relationship")
# Out:
# correlation coefficient: 0.310254279563729
# P-value: 1.5556730728881364e-141
# Reject null hypothesis: There is no relationship

# %%
df.columns
# Out:
# Index(['pickup', 'dropoff', 'passengers', 'distance', 'fare', 'tip', 'tolls',
#        'total', 'color', 'payment', 'pickup_zone', 'dropoff_zone',
#        'pickup_borough', 'dropoff_borough'],
#       dtype='object')

# %%
sns.histplot(df['tolls'],kde = True)
plt.show()

# %%
sns.scatterplot(x= df['tip'],y= df['tip'])
# Out:
# <Axes: xlabel='tip', ylabel='tip'>

# %%
df['tolls'].skew()
# Out:
# np.float64(4.876125068610457)

# %%
df['tolls'].kurtosis()
# Out:
# np.float64(32.159491595605495)

# %% [markdown]
# Hypothesis for correlation for numeric variables
# H0: correlation is zero
# H1: there is significant correlation (not zero)

# %%
r,p_val = stats.spearmanr(df['tip'],df['tolls'])
print("correlation coefficient:", r)
print("P-value:", p_val)
alpha = 0.05
if p_val< alpha:
  print("Reject null hypothesis: There is no relationship")
else:
  print("Fail to reject null hypothesis: There is significant relationship")
# Out:
# correlation coefficient: 0.175380002891528
# P-value: 5.643276180955435e-45
# Reject null hypothesis: There is no relationship

# %%
sns.histplot(df['distance'],kde = True)
plt.plot()
# Out:
# []

# %%
sns.scatterplot(x=df['tip'],y=df['distance'])
# Out:
# <Axes: xlabel='tip', ylabel='distance'>

# %%
df['distance'].skew()
# Out:
# np.float64(2.8870233381954415)

# %%
df['distance'].kurtosis()
# Out:
# np.float64(9.793001481080482)

# %% [markdown]
# Hypothesis for correlation for numeric variables
# H0: correlation is zero
# H1: there is significant correlation (not zero)

# %%
r,p_val = stats.spearmanr(df['tip'],df['distance'])
print("correlation coefficient:", r)
print("P-value:", p_val)
alpha = 0.05
if p_val< alpha:
  print("Reject null hypothesis: There is no relationship")
else:
  print("Fail to reject null hypothesis: There is significant relationship")
# Out:
# correlation coefficient: 0.29265085410043695
# P-value: 1.9411181331374707e-125
# Reject null hypothesis: There is no relationship

# %%
sns.histplot(df['total'],kde = True)
plt.show()

# %%
sns.scatterplot(x= df['tip'],y = df['total'])
# Out:
# <Axes: xlabel='tip', ylabel='total'>

# %%
df['total'].skew()
# Out:
# np.float64(2.635965898086771)

# %%
df['total'].kurtosis()
# Out:
# np.float64(9.67290848630777)

# %% [markdown]
# Hypothesis for correlation for numeric variables
# H0: correlation is zero
# H1: there is significant correlation (not zero)

# %%
r,p_val = stats.spearmanr(df['tip'],df['total'])
print("correlation coefficient:", r)
print("P-value:", p_val)
alpha = 0.05
if p_val< alpha:
  print("Reject null hypothesis: There is no relationship")
else:
  print("Fail to reject null hypothesis: There is significant relationship")
# Out:
# correlation coefficient: 0.5028299699182296
# P-value: 0.0
# Reject null hypothesis: There is no relationship

# %%
nm = df[['fare','distance','tip','passengers','tolls']]

# %%
sns.heatmap(nm.corr(method = "spearman"),annot = True ,cmap ='viridis')
# Out:
# <Axes: >

# %%
df['pickup'].dt.day
# Out:
# 0       23
# 1        4
# 2       27
# 3       10
# 4       30
#         ..
# 6336    31
# 6337    31
# 6338    23
# 6339     4
# 6340    13
# Name: pickup, Length: 6341, dtype: int32

# %%
df['pickup'].dt.month
# Out:
# 0       3
# 1       3
# 2       3
# 3       3
# 4       3
#        ..
# 6336    3
# 6337    3
# 6338    3
# 6339    3
# 6340    3
# Name: pickup, Length: 6341, dtype: int32

# %%
df['pickup'].dt.month_name()
# Out:
# 0       March
# 1       March
# 2       March
# 3       March
# 4       March
#         ...
# 6336    March
# 6337    March
# 6338    March
# 6339    March
# 6340    March
# Name: pickup, Length: 6341, dtype: object

# %%
df['pickup'].dt.year
# Out:
# 0       2019
# 1       2019
# 2       2019
# 3       2019
# 4       2019
#         ...
# 6336    2019
# 6337    2019
# 6338    2019
# 6339    2019
# 6340    2019
# Name: pickup, Length: 6341, dtype: int32

# %%
df['pickup'].dt.day_name()
# Out:
# 0        Saturday
# 1          Monday
# 2       Wednesday
# 3          Sunday
# 4        Saturday
#           ...
# 6336       Sunday
# 6337       Sunday
# 6338     Saturday
# 6339       Monday
# 6340    Wednesday
# Name: pickup, Length: 6341, dtype: object

# %%
df['pickup'].dt.quarter
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 6336    1
# 6337    1
# 6338    1
# 6339    1
# 6340    1
# Name: pickup, Length: 6341, dtype: int32

# %%
df['pickup'].dt.weekday
# Out:
# 0       5
# 1       0
# 2       2
# 3       6
# 4       5
#        ..
# 6336    6
# 6337    6
# 6338    5
# 6339    0
# 6340    2
# Name: pickup, Length: 6341, dtype: int32

# %%
df['pickup'].dt.hour
# Out:
# 0       20
# 1       16
# 2       17
# 3        1
# 4       13
#         ..
# 6336     9
# 6337    17
# 6338    22
# 6339    10
# 6340    19
# Name: pickup, Length: 6341, dtype: int32

# %%
df['pickup'].dt.minute
# Out:
# 0       21
# 1       11
# 2       53
# 3       23
# 4       27
#         ..
# 6336    51
# 6337    38
# 6338    55
# 6339     9
# 6340    31
# Name: pickup, Length: 6341, dtype: int32

# %%
df['pickup'].dt.second
# Out:
# 0        9
# 1       55
# 2        1
# 3       59
# 4       42
#         ..
# 6336    53
# 6337     0
# 6338    18
# 6339    25
# 6340    22
# Name: pickup, Length: 6341, dtype: int32

# %%
df['pickup'].dt.year
# Out:
# 0       2019
# 1       2019
# 2       2019
# 3       2019
# 4       2019
#         ...
# 6336    2019
# 6337    2019
# 6338    2019
# 6339    2019
# 6340    2019
# Name: pickup, Length: 6341, dtype: int32

# %%
df.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# ...

# %%
df = df.assign(
    pickup_month   = df['pickup'].dt.month_name(),
    pickup_year    = df['pickup'].dt.year,
    pickup_day     = df['pickup'].dt.day,
    pickup_dayname = df['pickup'].dt.day_name(),
    pickup_hour    = df['pickup'].dt.hour
)

# %%
df = df.assign(
    dropoff_month   = df['dropoff'].dt.month_name(),
    dropoff_year    = df['dropoff'].dt.year,
    dropoff_day     = df['dropoff'].dt.day,
    dropoff_dayname = df['dropoff'].dt.day_name(),
    dropoff_hour    = df['dropoff'].dt.hour,
    dropoff_minute  = df['dropoff'].dt.minute,
    dropoff_quarter = df['dropoff'].dt.quarter
)

# %%
df.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment  ... pickup_day pickup_dayname  \
# 0    0.0  12.95  yellow  credit card  ...         23       Saturday
# 1    0.0   9.30  yellow         cash  ...          4         Monday
# 2    0.0  14.16  yellow  credit card  ...         27      Wednesday
# 3    0.0  36.95  yellow  credit card  ...         10         Sunday
# 4    0.0  13.40  yellow  credit card  ...         30       Saturday
#
#   pickup_hour dropoff_month dropoff_year  dropoff_day  dropoff_dayname  \
# ...

# %% [markdown]
# Pickup_day
# H₀: There is NO relationship between pickup_day and tip
# H₁: There IS a relationship

# %%
from scipy.stats import spearmanr

r, p_val = spearmanr(df['pickup_day'], df['tip'])

print("Spearman r:", r)
print("P-value:", p_val)

if p_val < 0.05:
    print("Reject H₀: pickup_day affects tip")
else:
    print("Fail to reject H₀: pickup_day does NOT affect tip")
# Out:
# Spearman r: 0.00999688489379292
# P-value: 0.42607920373413977
# Fail to reject H₀: pickup_day does NOT affect tip

# %% [markdown]
# dropoff_day
# H₀: There is NO relationship between dropoff_day and tip
# H₁: There IS a relationship

# %%
r, p_val = spearmanr(df['dropoff_day'], df['tip'])
print("P-value:", p_val)
if p_val >= 0.05:
    print("dropoff_day is NOT significant → can be dropped")
# Out:
# P-value: 0.38854863611464274
# dropoff_day is NOT significant → can be dropped

# %% [markdown]
# dropoff_minute
# H₀: Mean tip is same across different dropoff minutes
# H₁: Mean tip differs

# %%
from scipy.stats import f_oneway

groups = [
    df[df['dropoff_minute'] == m]['tip']
    for m in df['dropoff_minute'].unique()
]

f_stat, p_val = f_oneway(*groups)

print("P-value:", p_val)

if p_val < 0.05:
    print("Reject H₀: dropoff_minute affects tip")
else:
    print("Fail to reject H₀: dropoff_minute does NOT affect tip")
# Out:
# P-value: 0.13819958833054127
# Fail to reject H₀: dropoff_minute does NOT affect tip

# %% [markdown]
# dropoff_quarter
# H₀: Mean tip is same across all quarters
# H₁: At least one quarter differs

# %%
df['dropoff_quarter'].unique()
# Out:
# array([1, 2], dtype=int32)

# %%
groups = [
    df[df['dropoff_quarter'] == q]['tip']
    for q in df['dropoff_quarter'].unique()
]

f_stat, p_val = f_oneway(*groups)

print("P-value:", p_val)

if p_val < 0.05:
    print("Reject H₀: Quarter affects tip")
else:
    print("Fail to reject H₀: Quarter does NOT affect tip")
# Out:
# P-value: 0.4035995080175966
# Fail to reject H₀: Quarter does NOT affect tip

# %% [markdown]
# pickup_year
# H₀: Mean tip is same across all years
# H₁: Mean tip differs

# %%
df['pickup_year'].nunique()
# Out:
# 1

# %%
df['dropoff_year'].nunique()
# Out:
# 1

# %% [markdown]
# pickup_hour
# H₀: There is no relationship between pickup_hour and tip
# H₁: There is a significant relationship

# %%
from scipy.stats import spearmanr

r, p_val = spearmanr(df['pickup_hour'], df['tip'])

print("p-value:", p_val)

if p_val < 0.05:
    print("Reject H₀ → pickup_hour significantly affects tip")
else:
    print("Fail to reject H₀ → consider dropping")
# Out:
# p-value: 7.517078284119937e-06
# Reject H₀ → pickup_hour significantly affects tip

# %% [markdown]
# pickup_dayname
# H₀: Mean tip is the same for all pickup days
# H₁: Mean tip differs for at least one day

# %%
from scipy.stats import f_oneway

groups = [
    df[df['pickup_dayname'] == d]['tip']
    for d in df['pickup_dayname'].unique()
]

f_stat, p_val = f_oneway(*groups)

print("p-value:", p_val)

if p_val < 0.05:
    print("Reject H₀ → pickup_dayname affects tip (KEEP)")
else:
    print("Fail to reject H₀ → weak feature")
# Out:
# p-value: 0.1242843162257308
# Fail to reject H₀ → weak feature

# %% [markdown]
# pickup_month
# H₀: Mean tip is the same across all pickup months
# H₁: Mean tip differs across months

# %%
groups = [
    df[df['pickup_month'] == m]['tip']
    for m in df['pickup_month'].unique()
]

f_stat, p_val = f_oneway(*groups)

if p_val < 0.05:
    print("Reject H₀ → pickup_month affects tip (KEEP)")
else:
  print("Fail to reject H₀ → weak feature")
# Out:
# Fail to reject H₀ → weak feature

# %% [markdown]
# dropoff_hour
# H₀: No relationship between dropoff_hour and tip
# H₁: Significant relationship exists

# %%
r, p_val = spearmanr(df['dropoff_hour'], df['tip'])

if p_val < 0.05:
    print("dropoff_hour significant → KEEP")
# Out:
# dropoff_hour significant → KEEP

# %% [markdown]
# dropoff_dayname
# H₀: Mean tip is same for all dropoff days
# H₁: Mean tip differs

# %%
groups = [
    df[df['dropoff_dayname'] == d]['tip']
    for d in df['dropoff_dayname'].unique()
]

f_stat, p_val = f_oneway(*groups)

if p_val < 0.05:
    print("dropoff_dayname significant → KEEP")

# %% [markdown]
# dropoff_month
# H₀: Mean tip is same across dropoff months
# H₁: Mean tip differs

# %%
groups = [
    df[df['dropoff_month'] == m]['tip']
    for m in df['dropoff_month'].unique()
]

f_stat, p_val = f_oneway(*groups)

if p_val < 0.05:
    print("dropoff_month significant → KEEP")

# %%
cols_to_drop = [
    'pickup',
    'pickup_year',
    'pickup_month',
    'pickup_day',




    'dropoff_day',
    'dropoff_minute',
    'dropoff_quarter',
    'dropoff_month',
    'dropoff_year',
    'dropoff'
]

# %%
df.drop(columns =cols_to_drop,inplace = True )

# %%
df.head()
# Out:
#    passengers  distance  fare   tip  tolls  total   color      payment  \
# 0           1      1.60   7.0  2.15    0.0  12.95  yellow  credit card
# 1           1      0.79   5.0  0.00    0.0   9.30  yellow         cash
# 2           1      1.37   7.5  2.36    0.0  14.16  yellow  credit card
# 3           1      7.70  27.0  6.15    0.0  36.95  yellow  credit card
# 4           3      2.16   9.0  1.10    0.0  13.40  yellow  credit card
#
#              pickup_zone           dropoff_zone pickup_borough  \
# 0        Lenox Hill West    UN/Turtle Bay South      Manhattan
# 1  Upper West Side South  Upper West Side South      Manhattan
# 2          Alphabet City           West Village      Manhattan
# 3              Hudson Sq         Yorkville West      Manhattan
# 4           Midtown East         Yorkville West      Manhattan
#
#   dropoff_borough pickup_dayname  pickup_hour dropoff_dayname  dropoff_hour
# 0       Manhattan       Saturday           20        Saturday            20
# ...

# %%
df.columns
# Out:
# Index(['passengers', 'distance', 'fare', 'tip', 'tolls', 'total', 'color',
#        'payment', 'pickup_zone', 'dropoff_zone', 'pickup_borough',
#        'dropoff_borough', 'pickup_dayname', 'pickup_hour', 'dropoff_dayname',
#        'dropoff_hour'],
#       dtype='object')

# %%
df.shape
# Out:
# (6341, 16)

# %%
df.columns
# Out:
# Index(['passengers', 'distance', 'fare', 'tip', 'tolls', 'total', 'color',
#        'payment', 'pickup_zone', 'dropoff_zone', 'pickup_borough',
#        'dropoff_borough', 'pickup_dayname', 'pickup_hour', 'dropoff_dayname',
#        'dropoff_hour'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6341 entries, 0 to 6340
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   passengers       6341 non-null   int64
#  1   distance         6341 non-null   float64
#  2   fare             6341 non-null   float64
#  3   tip              6341 non-null   float64
#  4   tolls            6341 non-null   float64
#  5   total            6341 non-null   float64
#  6   color            6341 non-null   object
#  7   payment          6341 non-null   object
#  8   pickup_zone      6341 non-null   object
#  9   dropoff_zone     6341 non-null   object
#  10  pickup_borough   6341 non-null   object
#  11  dropoff_borough  6341 non-null   object
#  12  pickup_dayname   6341 non-null   object
#  13  pickup_hour      6341 non-null   int32
#  14  dropoff_dayname  6341 non-null   object
#  15  dropoff_hour     6341 non-null   int32
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df['color'] = le.fit_transform(df['color'])
df['payment'] = le.fit_transform(df['payment'])

# %%
df = pd.get_dummies(
    df,
    columns=[
        'pickup_borough',
        'dropoff_borough',
        'pickup_dayname',
        'dropoff_dayname'
    ],
    drop_first=True
)

# %%
pickup_mean = df.groupby('pickup_zone')['tip'].mean()
dropoff_mean = df.groupby('dropoff_zone')['tip'].mean()

df['pickup_zone_enc'] = df['pickup_zone'].map(pickup_mean)
df['dropoff_zone_enc'] = df['dropoff_zone'].map(dropoff_mean)

df.drop(['pickup_zone', 'dropoff_zone'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6341 entries, 0 to 6340
# Data columns (total 31 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   passengers                     6341 non-null   int64
#  1   distance                       6341 non-null   float64
#  2   fare                           6341 non-null   float64
#  3   tip                            6341 non-null   float64
#  4   tolls                          6341 non-null   float64
#  5   total                          6341 non-null   float64
#  6   color                          6341 non-null   int64
#  7   payment                        6341 non-null   int64
#  8   pickup_hour                    6341 non-null   int32
#  9   dropoff_hour                   6341 non-null   int32
#  10  pickup_borough_Brooklyn        6341 non-null   bool
#  11  pickup_borough_Manhattan       6341 non-null   bool
# ...

# %%
X = df.drop(columns=['tip'])
y = df['tip']

# %%
print(X.shape)
print(y.shape)
# Out:
# (6341, 30)
# (6341,)

# %%
X.columns
# Out:
# Index(['passengers', 'distance', 'fare', 'tolls', 'total', 'color', 'payment',
#        'pickup_hour', 'dropoff_hour', 'pickup_borough_Brooklyn',
#        'pickup_borough_Manhattan', 'pickup_borough_Queens',
#        'dropoff_borough_Brooklyn', 'dropoff_borough_Manhattan',
#        'dropoff_borough_Queens', 'dropoff_borough_Staten Island',
#        'pickup_dayname_Monday', 'pickup_dayname_Saturday',
#        'pickup_dayname_Sunday', 'pickup_dayname_Thursday',
#        'pickup_dayname_Tuesday', 'pickup_dayname_Wednesday',
#        'dropoff_dayname_Monday', 'dropoff_dayname_Saturday',
#        'dropoff_dayname_Sunday', 'dropoff_dayname_Thursday',
#        'dropoff_dayname_Tuesday', 'dropoff_dayname_Wednesday',
#        'pickup_zone_enc', 'dropoff_zone_enc'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size = 0.25,random_state = 42)

# %%
print('X train shape: ',x_train.shape)
print('X test shape: ',x_test.shape)
print('Y train shape: ',y_train.shape)
print('Y test shape: ',y_test.shape)
# Out:
# X train shape:  (4755, 30)
# X test shape:  (1586, 30)
# Y train shape:  (4755,)
# Y test shape:  (1586,)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([-1.43094473e-02, -3.86044568e-03, -7.46850192e-01, -7.41233909e-01,
#         7.62472088e-01, -8.62042119e-01,  5.45020817e-01, -1.69228219e-02,
#        -7.61303285e-04, -1.50649146e-01, -3.69068195e-01,  1.48114212e-01,
#        -1.15228951e-01, -6.19926657e-01, -9.86119618e-02,  9.20803901e-01,
#        -9.92762477e-02,  5.73656832e-02,  2.04540175e-01, -5.00754668e-01,
#         1.22868917e-01, -1.80987927e-01,  1.47323911e-01,  1.13907081e-01,
#        -4.54653907e-02,  4.53657535e-01, -1.31925248e-01,  2.31123930e-01,
#         5.33695655e-02,  1.65968937e-02])

# %%
model.intercept_
# Out:
# np.float64(-0.882817883701545)

# %% [markdown]
# Training Score

# %%
y_train_pred = model.predict(x_train)
train_score = model.score(x_train,y_train)
print('Train score: ',train_score)
# Out:
# Train score:  0.9327775322484754

# %%
y_test_pred = model.predict(x_test)
test_score = model.score(x_test,y_test)
print('Test score: ',test_score)
# Out:
# Test score:  0.9358929407107968

# %% [markdown]
# Performance Metrics

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score,root_mean_squared_error

# %%
rmse = root_mean_squared_error(y_train,y_train_pred)
print('RMSE: ',rmse)
# Out:
# RMSE:  0.6124626306363977

# %%
rmse = root_mean_squared_error(y_test,y_test_pred)
print('RMSE: ',rmse)
# Out:
# RMSE:  0.5975511733937581

# %%
mse = mean_squared_error(y_train,y_train_pred)
print('MSE: ',mse)
# Out:
# MSE:  0.37511047392605656

# %%
mse = mean_squared_error(y_test,y_test_pred)
print('MSE: ',mse)
# Out:
# MSE:  0.35706740482425714

# %%
mae = mean_absolute_error(y_train,y_train_pred)
print('MSE: ',mae)
# Out:
# MSE:  0.4123944733490606

# %%
mae = mean_absolute_error(y_test,y_test_pred)
print('MSE: ',mae)
# Out:
# MSE:  0.39721761149262663

# %%
r2 = r2_score(y_train,y_train_pred)
print('R2: ',r2)
# Out:
# R2:  0.9327775322484754

# %%
r2 = r2_score(y_test,y_test_pred)
print('R2: ',r2)
# Out:
# R2:  0.9358929407107968

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error, r2_score

# %%
from sklearn.pipeline import make_pipeline

poly_model = make_pipeline(
    PolynomialFeatures(2),
    LinearRegression()
)

# %%
poly_model.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures()),
#                 ('linearregression', LinearRegression())])

# %%
y_train_pred = poly_model.predict(x_train)
y_test_pred = poly_model.predict(x_test)

# %%
print("Train MSE:", mean_squared_error(y_train, y_train_pred))
print("Test MSE :", mean_squared_error(y_test, y_test_pred))

print("Train R2:", r2_score(y_train, y_train_pred))
print("Test R2 :", r2_score(y_test, y_test_pred))
# Out:
# Train MSE: 0.16242462965053242
# Test MSE : 224.17056840790337
# Train R2: 0.9708923498870667
# Test R2 : -39.24706743224851

# %%
lin = LinearRegression()
lin.fit(x_train, y_train)

y_lin_pred = lin.predict(x_test)

print("Linear R2:", r2_score(y_test, y_lin_pred))
print("Polynomial R2:", r2_score(y_test, y_test_pred))
# Out:
# Linear R2: 0.9358929407107968
# Polynomial R2: -39.24706743224851

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import Ridge

poly_model = make_pipeline(
    StandardScaler(),
    PolynomialFeatures(degree=2, include_bias=False),
    Ridge(alpha=1.0)
)

poly_model.fit(x_train, y_train)
y_test_pred = poly_model.predict(x_test)

from sklearn.metrics import r2_score
print("Polynomial R2:", r2_score(y_test, y_test_pred))
# Out:
# Polynomial R2: 0.9480524430753742

# %% [markdown]
# we can choose linear regression on simplicity.. even small improvement in r2_score of polynomial regression compared to linear regression..simplicity preferred over 1.2% improvement
